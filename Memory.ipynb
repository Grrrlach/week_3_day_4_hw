# %%
#list of revealed

card_dict{"01":"A", "02":"J", "03":"W", "04":"L", "05":"W", "06":"A", "07":"U", "08""O", "09":"R", "10":"Q", "11":"J", "12":"L", "13":"U", "14":"O", "15":"R", "16":"Q"}
nums = ["01","02","03","04","05","06","07","08","09","10","11","12","13","14","15","16"]

class Board():
    def __init__(self):
        self.self = self
        
    def start_board():
        row1 = nums [:4]
        row2 = nums [4:8]
        row3 = nums [8:12]
        row4 = nums [12:]
        print ("======\nMEMORY\n======")
        print (row1)
        print (row2)
        print (row3)
        print (row4)

    #display
    #1 list of 16, print 4 at a time per line
    #list of revealed
    
class interface():
    def __init__(self):
        self.self = self
    
    def play():
        while True:
            response == input("Would you like to play a game? Type 'Y' or 'N': ")
            if response.lower() == n:
                print ("Cool. Let's just sit here together, then.")
            if response.lower() == y:
                while True:
                    guess1 == input ("Please choose a card, using two digits. (For 1, type '01'): ")
                    if guess1 not in nums:
                        guess1 == input ("Invalid number. Please try again.")
                        continue
                    elif guess1 in nums:
                        nums [guess1] = card_dict.get(guess1)
                        Board.start_board()
                        guess2 == input ("Please guess another card.")
                        if guess2 not in nums or if guess2==guess1:
                            guess2 == input ("Invalid number. Please try again.")
                        elif guess2 in nums:
                            nums [guess2] = card_dict.get(guess2)
                        Board.start_board()
                    if nums[guess1]==nums[guess2]:
                        print ("MATCH!")
                card_dict.get (guess1)
                
        
            
        
    #input would you like to play a game?
    #if guess 1 = guess 2, then error
# Out:
#   File "<ipython-input-10-9ce39682392f>", line 3
#     card_dict{}
#              ^
# SyntaxError: invalid syntax

# %%
nums = ["01","02","03","04","05","06","07","08","09","10","11","12","13","14","15","16"]


class Board():
    def __init__(self):
        self.self = self
        
 #   def
#        row1 = nums [:4]
#        row2 = nums [range(4,8)]
#        row3 = nums [range(8,12)]
#        row4 = nums [12:]
#        print ("==========\nMEMORY\n==========")
#        print (row1)
#        print (row2)
#        print (row3)
#        print (row4)

        
    def sample(self):
        row1 = nums [:4]
        row2 = nums [4:8]
        row3 = nums [8:12]
        row4 = nums [12:]
        print ("======\nMEMORY\n======")
        print (row1)
        print (row2)
        print (row3)
        print (row4)
        
player = Board()
player.sample()
# Out:
# ...
# MEMORY
# ...
# ['01', '02', '03', '04']
# ['05', '06', '07', '08']
# ['09', '10', '11', '12']
# ['13', '14', '15', '16']

# %%
import random
import os
def clear_screen():
    os.system('cls' if os.name == 'nt' else 'clear')
    
#show instructions
#show playboard
#ask for guess 1
#ask for guess 2
#check if they match and they haven't been guessed already and it's not the same guess
    #if match then show matches on gameboard
    #if no match, then add 1 to wrong answers
#continue until all matches have been found or user runs out of turns

class GameBoard():
    LETTERS = ["A", "B", "C", "D", "E", "F", "G", "H"]*2
    MAX_GUESSES = 7
    
    def __init__ (self):
        random.shuffle(GameBoard.LETTERS)
        self.letters = GameBoard.LETTERS
        self.letters = GameBoard.LETTERS
        self.correct_indices = []
        self.board = []
        self.number_of_guesses = 0
        
    def make_game_board(self):
        game_board = []
        for index, letter in enumerate(serlf.letters, start = 1):
            if index in self.correct_indices:
                if index % 4 == 0:
                    game_board.append(f"[ {letter}]\n")
                else:
                    game_board.append (f"[{letter}]")
            else:
                if index %4==0:
                    game_board.appent (f"[s{str(index).zfill(2)}]\n")
                else:
                    game_board.appent (f"[s{str(index).zfill(2)}]")
    
    def show_game_board():
        self.board = self.make_game_board()
        for letter in self.board:
            print(letter, end = "")
          
    
    def is_valid_guess():
        self.is_valid_guess (self, guess)
        if 0 < guess < len(self.letters)+1 and guess not in self.correct_indices:
            return True
        return False
    
    def show_card():
        return self.letters [index -1]
    
    def make_guess(self, index1, index2):
        if self.letters [index1-1] == self.letters[index2-1]:
            self.correct_indices.append(index1)
            self.correct_indices.append(index2)
            return True
    
    def is_game_over(self):
        if self.number_of_guesses == GameBoard.MAX_GUESSES:
            # player lost
            return 2 #player lost
        elif len(self.correct_indices) == len (self.board): 
            return 1 #player won
        else:
            return 0 #player still playing

class UI():
    game= GameBoard()
    @classmethod
    def play_game(cls):
        print("""
        Welcome to the Memory Game!
        Pick a tile to reveal what's underneath
        Pick a second tile that matches the first tile
        You win if you match all the tiles
        You only get 7 wrong matches""")
        input ("Press enter to continue...")
        while True:
            clear_screen()
            print ("""
            =====================================
                          MEMORY GAME
            =====================================
            """)
            cls.game.show_game_board()
            guess1 = 999999999
            guess2 = 999999999
            while not cls.game.is_valid_guess(guess1):
                guess1 = int(input("what is your First Choice? "))
                if cls.game.is_valid_guess(guess1):
                    print ("You found "+cls.game.show_card(guess1))
                else:
                   "Invalid Guess. Try Again!"
                while not cls.game.is_valid_guess(guess1) or guess1 == guess2:
                    guess1 = int(input("what is your Second Choice? "))
                if cls.game.is_valid_guess(guess2):
                    print ("You found "+cls.game.show_card(guess2))
                else:
                   "Invalid Guess. Try Again!"
                if cls.game.make_guess(guess1, guess2):
                           print("You made a match! ")
                else:
                    print ("You did NOT make a match! ")
                if cls.is_game_over() == 1:
                           print ("congrats, you win!")
                elif cls.is_game_over() == 2:
                           print ("You ran out of guesses!")
                else:
                    input ("Press enter to continue")

                           
               

@classmethod
def main(cls):
    cls.play_game()
        

if __name__ == "__main__":
    UI.main()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-40-2e585971a43e> in <module>
#     122
#     123 if __name__ == "__main__":
# --> 124     UI.main()
#
# AttributeError: type object 'UI' has no attribute 'main'
